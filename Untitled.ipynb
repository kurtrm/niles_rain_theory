# %%
import numpy as np
import scipy.stats as scs
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
df = pd.read_csv('/mnt/c/Users/kurtrm/Downloads/1306116.csv')

# %%
df
# Out:
#         STATION                                               NAME  \
# 0   USC00456295                                PALMER 3 ESE, WA US
# 1   USW00024222                EVERETT SNOHOMISH CO AIRPORT, WA US
# 2   USW00024233        SEATTLE TACOMA INTERNATIONAL AIRPORT, WA US
# 3   USC00458278                             TACOMA NUMBER 1, WA US
# 4   USW00094274                      TACOMA NARROWS AIRPORT, WA US
# 5   USC00459021                                   WAUNA 3 W, WA US
# 6   USW00094290  SEATTLE SAND POINT WEATHER FORECAST OFFICE, WA US
# 7   USW00024234                        SEATTLE BOEING FIELD, WA US
# 8   USC00458508                   TOLT SOUTH FORK RESERVOIR, WA US
# 9   USC00454486                                   LANDSBURG, WA US
# 10  USW00094248                    RENTON MUNICIPAL AIRPORT, WA US
# 11  USC00451233                                  CEDAR LAKE, WA US
# 12  USC00452675                                     EVERETT, WA US
# 13  USC00455525                                      MONROE, WA US
# 14  USC00457773                            SNOQUALMIE FALLS, WA US
# 15  USC00450872                                   BREMERTON, WA US
# 16  USC00454169                                        KENT, WA US
#
#           DATE  PRCP  SNOW  TAVG  TMAX  TMIN  TOBS
# 0   2000-01-01  0.68   0.0   NaN  43.0  33.0  35.0
# 1   2000-01-01  0.39   NaN  39.0  42.0  35.0   NaN
# 2   2000-01-01  0.27   NaN  40.0  43.0  37.0   NaN
# 3   2000-01-01  0.43   0.0   NaN  47.0  37.0  43.0
# 4   2000-01-01  0.35   NaN  40.0  43.0  36.0   NaN
# 5   2000-01-01  0.34   0.0   NaN   NaN   NaN   NaN
# 6   2000-01-01  0.07   NaN  42.0  44.0  39.0   NaN
# 7   2000-01-01  0.27   NaN  42.0  45.0  39.0   NaN
# 8   2000-01-01  1.66   0.0   NaN   NaN   NaN   NaN
# 9   2000-01-01  0.32   0.0   NaN  43.0  36.0  39.0
# 10  2000-01-01  0.27   NaN  42.0  45.0  39.0   NaN
# 11  2000-01-01  0.78   0.0   NaN  41.0  31.0  34.0
# 12  2000-01-01  0.50   NaN   NaN   NaN   NaN   NaN
# 13  2000-01-01  0.16   0.0   NaN  45.0  38.0  40.0
# 14  2000-01-01  0.72   0.0   NaN  44.0  36.0  38.0
# 15  2000-01-01  0.23   0.0   NaN  44.0  38.0  40.0
# 16  2000-01-01  0.32   0.0   NaN  47.0  36.0  42.0

# %%
17 * 5
# Out:
# 85
